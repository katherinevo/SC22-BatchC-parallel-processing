# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [807], in <cell line: 6>()
#       4 logreg=LogisticRegression()
#       5 logreg_cv=GridSearchCV(logreg,grid,cv=10)
# ----> 6 logreg_cv.fit(x_train,y_train)
#       8 print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
#       9 print("accuracy :",logreg_cv.best_score_)
#
# NameError: name 'x_train' is not defined

# %%
heart = pd.read_csv('Data/heart data.csv')

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
X = heart.drop(['target'], axis = 1)
y = heart['target']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.80)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_hat = clf.predict(X_test)
y_hat
# Out:
#   Input In [111]
#     from sklearn.linear_model
#                              ^
# SyntaxError: invalid syntax

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_hat, y_test)
# Out:
# 0.8292682926829268

# %%
from sklearn.metrics import recall_score
recall_score(y_hat, y_test)
# Out:
# 0.8141592920353983

# %%
from sklearn.metrics import confusion_matrix

px.imshow(confusion_matrix(y_hat, y_test), text_auto = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
corr = heart.corr()
sns.heatmap(corr, annot=True)
sns.set(rc = {'figure.figsize':(20,10)})

# %%
drop_these = ['exang', 'oldpeak', 'slope']

# %%
heart.drop(drop_these, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 heart.drop(drop_these, axis=1, inplace=True)
#
# NameError: name 'drop_these' is not defined

# %%
heart = px.thalach.()
# Out:
#   Input In [448]
#     heart = px.thalach.()
#                        ^
# SyntaxError: invalid syntax

# %%
heart = heart[(heart.thalach <200)]

# %%
heart = heart[(heart.chol <500)]

# %%
heart = heart[(heart.trestbps <190)]

# %%
sns.catplot(x='age', y='trestbps',
           hue = 'sex',
           data=heart,
          height = 10, aspect=10/10)
